# %%
import pandas as pd

# %%
file = 'MLSAttendanceAllGames.csv'
table = pd.read_csv(file)

# %%
table
# Out:
#       Game #      Date         Home  Home G      Visitor  Visitor G     Att  \
# 0        1.0    4/6/96       HOU/SJ     1.0    DC United        0.0  31,683
# 1        2.0   4/13/96    Tampa Bay     3.0  New England        2.0  26,473
# 2        3.0   4/13/96     Columbus     4.0    DC United        0.0  25,266
# 3        4.0   4/13/96  Kansas City     3.0     Colorado        0.0  21,141
# 4        5.0   4/13/96  Los Angeles     2.0        NJ/NY        1.0  69,255
# ...      ...       ...          ...     ...          ...        ...     ...
# 5466   390.0  10/28/18    Vancouver     2.0     Portland        1.0  25,348
# 5467   391.0  10/28/18     Columbus     3.0    Minnesota        2.0  17,677
# 5468     NaN       NaN          NaN     NaN          NaN        NaN     NaN
# 5469     NaN       NaN          NaN     NaN          NaN        NaN     NaN
# 5470     NaN       NaN          NaN     NaN          NaN        NaN     NaN
#
#                Home Parent          Visitor Parent             Staduim  \
# 0           Houston Dynamo               DC United     Spartan Stadium
# 1         Tampa Bay Mutiny  New England Revolution  Houlihan's Stadium
# 2         Columbus Crew SC               DC United        Ohio Stadium
# 3     Sporting Kansas City         Colorado Rapids   Arrowhead Stadium
# 4                LA Galaxy       New York Red Bull           Rose Bowl
# ...                    ...                     ...                 ...
# 5466    Vancuver Whitecaps        Portland Timbers            BC Place
# 5467      Columbus Crew SC        Minnesota United      Mapfre Stadium
# 5468                   NaN                     NaN                 NaN
# 5469                   NaN                     NaN                 NaN
# 5470                   NaN                     NaN                 NaN
#
#       Capacity Percentage Filled
# 0      30456.0              104%
# 1      16000.0              165%
# 2      25243.0              100%
# 3      20269.0              104%
# 4      26000.0              266%
# ...        ...               ...
# 5466   22120.0              115%
# 5467   19968.0               89%
# 5468       NaN               NaN
# 5469       NaN               NaN
# 5470       NaN               NaN
#
# [5471 rows x 12 columns]

# %%
table.dropna(inplace=True)
table
# Out:
#       Game #      Date         Home  Home G      Visitor  Visitor G     Att  \
# 0        1.0    4/6/96       HOU/SJ     1.0    DC United        0.0  31,683
# 1        2.0   4/13/96    Tampa Bay     3.0  New England        2.0  26,473
# 2        3.0   4/13/96     Columbus     4.0    DC United        0.0  25,266
# 3        4.0   4/13/96  Kansas City     3.0     Colorado        0.0  21,141
# 4        5.0   4/13/96  Los Angeles     2.0        NJ/NY        1.0  69,255
# ...      ...       ...          ...     ...          ...        ...     ...
# 5463   387.0  10/28/18        NJ/NY     1.0      Orlando        0.0  20,023
# 5464   388.0  10/28/18      Seattle     2.0     San Jose        1.0  42,617
# 5465   389.0  10/28/18      Toronto     4.0      Atlanta        1.0  23,895
# 5466   390.0  10/28/18    Vancouver     2.0     Portland        1.0  25,348
# 5467   391.0  10/28/18     Columbus     3.0    Minnesota        2.0  17,677
#
#                Home Parent          Visitor Parent             Staduim  \
# 0           Houston Dynamo               DC United     Spartan Stadium
# 1         Tampa Bay Mutiny  New England Revolution  Houlihan's Stadium
# 2         Columbus Crew SC               DC United        Ohio Stadium
# 3     Sporting Kansas City         Colorado Rapids   Arrowhead Stadium
# 4                LA Galaxy       New York Red Bull           Rose Bowl
# ...                    ...                     ...                 ...
# 5463     New York Red Bull         Orlando City SC      Red Bull Arena
# 5464   Seattle Sounders FC    San Jose Earthquakes   CenturyLink Field
# 5465            Toronto FC          Atlanta United           BMO Field
# 5466    Vancuver Whitecaps        Portland Timbers            BC Place
# 5467      Columbus Crew SC        Minnesota United      Mapfre Stadium
#
#       Capacity Percentage Filled
# 0      30456.0              104%
# 1      16000.0              165%
# 2      25243.0              100%
# 3      20269.0              104%
# 4      26000.0              266%
# ...        ...               ...
# 5463   25000.0               80%
# 5464   39419.0              108%
# 5465   30000.0               80%
# 5466   22120.0              115%
# 5467   19968.0               89%
#
# [5468 rows x 12 columns]

# %%
mls_game = table[['Game #', 'Date', 'Home', 'Home Parent', 'Home G', 'Visitor Parent', 'Visitor G', 'Att', 'Staduim', 'Percentage Filled']].copy()

# %%
mls_game
# Out:
#       Game #      Date         Home           Home Parent  Home G  \
# 0        1.0    4/6/96       HOU/SJ        Houston Dynamo     1.0
# 1        2.0   4/13/96    Tampa Bay      Tampa Bay Mutiny     3.0
# 2        3.0   4/13/96     Columbus      Columbus Crew SC     4.0
# 3        4.0   4/13/96  Kansas City  Sporting Kansas City     3.0
# 4        5.0   4/13/96  Los Angeles             LA Galaxy     2.0
# ...      ...       ...          ...                   ...     ...
# 5463   387.0  10/28/18        NJ/NY     New York Red Bull     1.0
# 5464   388.0  10/28/18      Seattle   Seattle Sounders FC     2.0
# 5465   389.0  10/28/18      Toronto            Toronto FC     4.0
# 5466   390.0  10/28/18    Vancouver    Vancuver Whitecaps     2.0
# 5467   391.0  10/28/18     Columbus      Columbus Crew SC     3.0
#
#               Visitor Parent  Visitor G     Att             Staduim  \
# 0                  DC United        0.0  31,683     Spartan Stadium
# 1     New England Revolution        2.0  26,473  Houlihan's Stadium
# 2                  DC United        0.0  25,266        Ohio Stadium
# 3            Colorado Rapids        0.0  21,141   Arrowhead Stadium
# 4          New York Red Bull        1.0  69,255           Rose Bowl
# ...                      ...        ...     ...                 ...
# 5463         Orlando City SC        0.0  20,023      Red Bull Arena
# 5464    San Jose Earthquakes        1.0  42,617   CenturyLink Field
# 5465          Atlanta United        1.0  23,895           BMO Field
# 5466        Portland Timbers        1.0  25,348            BC Place
# 5467        Minnesota United        2.0  17,677      Mapfre Stadium
#
#      Percentage Filled
# 0                 104%
# 1                 165%
# 2                 100%
# 3                 104%
# 4                 266%
# ...                ...
# 5463               80%
# 5464              108%
# 5465               80%
# 5466              115%
# 5467               89%
#
# [5468 rows x 10 columns]

# %%
mls_game.columns = ['Game #', 'Date', 'City', 'Home Team', 'Home Goals', 'Visitor Team', 'Visitor Goals', 'Attendance', 'Staduim', 'Percentage Filled']
mls_game
# Out:
#       Game #      Date         City             Home Team  Home Goals  \
# 0        1.0    4/6/96       HOU/SJ        Houston Dynamo         1.0
# 1        2.0   4/13/96    Tampa Bay      Tampa Bay Mutiny         3.0
# 2        3.0   4/13/96     Columbus      Columbus Crew SC         4.0
# 3        4.0   4/13/96  Kansas City  Sporting Kansas City         3.0
# 4        5.0   4/13/96  Los Angeles             LA Galaxy         2.0
# ...      ...       ...          ...                   ...         ...
# 5463   387.0  10/28/18        NJ/NY     New York Red Bull         1.0
# 5464   388.0  10/28/18      Seattle   Seattle Sounders FC         2.0
# 5465   389.0  10/28/18      Toronto            Toronto FC         4.0
# 5466   390.0  10/28/18    Vancouver    Vancuver Whitecaps         2.0
# 5467   391.0  10/28/18     Columbus      Columbus Crew SC         3.0
#
#                 Visitor Team  Visitor Goals Attendance             Staduim  \
# 0                  DC United            0.0     31,683     Spartan Stadium
# 1     New England Revolution            2.0     26,473  Houlihan's Stadium
# 2                  DC United            0.0     25,266        Ohio Stadium
# 3            Colorado Rapids            0.0     21,141   Arrowhead Stadium
# 4          New York Red Bull            1.0     69,255           Rose Bowl
# ...                      ...            ...        ...                 ...
# 5463         Orlando City SC            0.0     20,023      Red Bull Arena
# 5464    San Jose Earthquakes            1.0     42,617   CenturyLink Field
# 5465          Atlanta United            1.0     23,895           BMO Field
# 5466        Portland Timbers            1.0     25,348            BC Place
# 5467        Minnesota United            2.0     17,677      Mapfre Stadium
#
#      Percentage Filled
# 0                 104%
# 1                 165%
# 2                 100%
# 3                 104%
# 4                 266%
# ...                ...
# 5463               80%
# 5464              108%
# 5465               80%
# 5466              115%
# 5467               89%
#
# [5468 rows x 10 columns]
